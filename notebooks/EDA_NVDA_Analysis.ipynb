# %%
# Import neccessary python liberaries
import os
import sys
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk

sys.path.insert(0, os.path.dirname(os.getcwd()))

from scripts.EDA_Stock_Analysis import *

# Suppress FutureWarnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# file path
file_path='../raw_analyst_ratings/raw_analyst_ratings.csv'
# create an object
text_analyser=TextAnalysis(file_path)

# %%
text_analyser.load_data()
# Out:
#          Unnamed: 0                                           headline  \
# 0                 0            Stocks That Hit 52-Week Highs On Friday
# 1                 1         Stocks That Hit 52-Week Highs On Wednesday
# 2                 2                      71 Biggest Movers From Friday
# 3                 3       46 Stocks Moving In Friday's Mid-Day Session
# 4                 4  B of A Securities Maintains Neutral on Agilent...
# ...             ...                                                ...
# 1407323     1413844             Top Narrow Based Indexes For August 29
# 1407324     1413845  Recap: Wednesday's Top Percentage Gainers and ...
# 1407325     1413846  UPDATE: Oppenheimer Color on China Zenix Auto ...
# 1407326     1413847  Oppenheimer Initiates China Zenix At Outperfor...
# 1407327     1413848  China Zenix Auto International Opens For Tradi...
#
#                                                        url          publisher  \
# 0        https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1        https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2        https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3        https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4        https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
# ...                                                    ...                ...
# 1407323  https://www.benzinga.com/news/11/08/1888782/to...      Monica Gerson
# 1407324  https://www.benzinga.com/news/earnings/11/06/1...       Benjamin Lee
# 1407325  https://www.benzinga.com/analyst-ratings/analy...     BenzingaStaffL
# 1407326  https://www.benzinga.com/analyst-ratings/price...          Joe Young
# 1407327  https://www.benzinga.com/news/ipos/11/05/10789...      Allie Wickman
#
#                               date stock
# 0        2020-06-05 10:30:54-04:00     A
# 1        2020-06-03 10:45:20-04:00     A
# 2        2020-05-26 04:30:07-04:00     A
# 3        2020-05-22 12:45:06-04:00     A
# 4        2020-05-22 11:38:59-04:00     A
# ...                            ...   ...
# 1407323        2011-08-29 00:00:00    ZX
# 1407324        2011-06-22 00:00:00    ZX
# 1407325        2011-06-21 00:00:00    ZX
# 1407326        2011-06-21 00:00:00    ZX
# 1407327        2011-05-12 00:00:00    ZX
#
# [1407328 rows x 6 columns]

# %%
# Drop column name "Unnamed"
text_analyser.drop_unnamed_column()
# Out:
#                                                   headline  \
# 0                  Stocks That Hit 52-Week Highs On Friday
# 1               Stocks That Hit 52-Week Highs On Wednesday
# 2                            71 Biggest Movers From Friday
# 3             46 Stocks Moving In Friday's Mid-Day Session
# 4        B of A Securities Maintains Neutral on Agilent...
# ...                                                    ...
# 1407323             Top Narrow Based Indexes For August 29
# 1407324  Recap: Wednesday's Top Percentage Gainers and ...
# 1407325  UPDATE: Oppenheimer Color on China Zenix Auto ...
# 1407326  Oppenheimer Initiates China Zenix At Outperfor...
# 1407327  China Zenix Auto International Opens For Tradi...
#
#                                                        url          publisher  \
# 0        https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1        https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2        https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3        https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4        https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
# ...                                                    ...                ...
# 1407323  https://www.benzinga.com/news/11/08/1888782/to...      Monica Gerson
# 1407324  https://www.benzinga.com/news/earnings/11/06/1...       Benjamin Lee
# 1407325  https://www.benzinga.com/analyst-ratings/analy...     BenzingaStaffL
# 1407326  https://www.benzinga.com/analyst-ratings/price...          Joe Young
# 1407327  https://www.benzinga.com/news/ipos/11/05/10789...      Allie Wickman
#
#                               date stock
# 0        2020-06-05 10:30:54-04:00     A
# 1        2020-06-03 10:45:20-04:00     A
# 2        2020-05-26 04:30:07-04:00     A
# 3        2020-05-22 12:45:06-04:00     A
# 4        2020-05-22 11:38:59-04:00     A
# ...                            ...   ...
# 1407323        2011-08-29 00:00:00    ZX
# 1407324        2011-06-22 00:00:00    ZX
# 1407325        2011-06-21 00:00:00    ZX
# 1407326        2011-06-21 00:00:00    ZX
# 1407327        2011-05-12 00:00:00    ZX
#
# [1407328 rows x 5 columns]

# %%
#check code quality
text_analyser.check_data_quality()
# Out:
# Missing values:
# headline     0
# url          0
# publisher    0
# date         0
# stock        0
# dtype: int64
#
#  Number of duplicates: 1
#
#  Data types:
# headline     object
# url          object
# publisher    object
# date         object
# stock        object
# dtype: object

# %%
# headline length statistics
summery=text_analyser.headline_length_stats()
print(summery)
# Out:
# Headline Length Statistics:
# count    1.407328e+06
# mean     7.312051e+01
# std      4.073531e+01
# min      3.000000e+00
# 25%      4.700000e+01
# 50%      6.400000e+01
# 75%      8.700000e+01
# max      5.120000e+02
# Name: headline_length, dtype: float64

# %%
# Count the number of articles per publisher to identify which publishers are most active.
articles_per_publisher=text_analyser.article_per_publisher()
articles_per_publisher
# Out:
# Article Counts per Publisher:
#               Publisher  Article Count
# 0         Paul Quintaro         228373
# 1            Lisa Levin         186979
# 2     Benzinga Newsdesk         150484
# 3         Charles Gross          96732
# 4         Monica Gerson          82380
# ...                 ...            ...
# 1029          MoneyGeek              1
# 1030             muathe              1
# 1031      Robert Morris              1
# 1032    LeftCoastHedgie              1
# 1033     Jeremie Capron              1
#
# [1034 rows x 2 columns]

# %%
articles_over_time, articles_by_day = text_analyser.analyze_publication_dates()
print("Articles over time: \n", articles_over_time)
print("Articles by day: \n", articles_by_day)
# Out:
# Articles over time:
#         year  month  article_count
# 0    2011.0    4.0              6
# 1    2011.0    5.0             78
# 2    2011.0    6.0             95
# 3    2011.0    7.0            137
# 4    2011.0    8.0            149
# ..      ...    ...            ...
# 106  2020.0    2.0           2355
# 107  2020.0    3.0           4681
# 108  2020.0    4.0           4616
# 109  2020.0    5.0           9333
# 110  2020.0    6.0           5990
#
# [111 rows x 3 columns]
# Articles by day:
#  day_of_week
# Thursday     12712
# Wednesday    11873
# Tuesday      11037
# Monday       10297
# Friday        9407
# Sunday         388
# Saturday       273
# Name: count, dtype: int64

# %%
text_analyser.plot_article_trends(articles_over_time, articles_by_day)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\getie\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
cleand_data=text_analyser.text_preprocess()
cleand_data
# Out:
#                                                   headline  \
# 0                  Stocks That Hit 52-Week Highs On Friday
# 1               Stocks That Hit 52-Week Highs On Wednesday
# 2                            71 Biggest Movers From Friday
# 3             46 Stocks Moving In Friday's Mid-Day Session
# 4        B of A Securities Maintains Neutral on Agilent...
# ...                                                    ...
# 1407323             Top Narrow Based Indexes For August 29
# 1407324  Recap: Wednesday's Top Percentage Gainers and ...
# 1407325  UPDATE: Oppenheimer Color on China Zenix Auto ...
# 1407326  Oppenheimer Initiates China Zenix At Outperfor...
# 1407327  China Zenix Auto International Opens For Tradi...
#
#                                                        url          publisher  \
# 0        https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1        https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2        https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3        https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4        https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
# ...                                                    ...                ...
# 1407323  https://www.benzinga.com/news/11/08/1888782/to...      Monica Gerson
# 1407324  https://www.benzinga.com/news/earnings/11/06/1...       Benjamin Lee
# 1407325  https://www.benzinga.com/analyst-ratings/analy...     BenzingaStaffL
# 1407326  https://www.benzinga.com/analyst-ratings/price...          Joe Young
# 1407327  https://www.benzinga.com/news/ipos/11/05/10789...      Allie Wickman
#
#                              date stock  headline_length    year  month  \
# 0       2020-06-05 14:30:54+00:00     A               39  2020.0    6.0
# 1       2020-06-03 14:45:20+00:00     A               42  2020.0    6.0
# 2       2020-05-26 08:30:07+00:00     A               29  2020.0    5.0
# 3       2020-05-22 16:45:06+00:00     A               44  2020.0    5.0
# 4       2020-05-22 15:38:59+00:00     A               87  2020.0    5.0
# ...                           ...   ...              ...     ...    ...
# 1407323                       NaT    ZX               38     NaN    NaN
# 1407324                       NaT    ZX               52     NaN    NaN
# 1407325                       NaT    ZX               56     NaN    NaN
# 1407326                       NaT    ZX               54     NaN    NaN
# 1407327                       NaT    ZX               81     NaN    NaN
#
#         day_of_week                                   cleaned_headline
# 0            Friday                       stocks hit week highs friday
# 1         Wednesday                    stocks hit week highs wednesday
# 2           Tuesday                              biggest movers friday
# 3            Friday               stocks moving fridays midday session
# 4            Friday  b securities maintains neutral agilent technol...
# ...             ...                                                ...
# 1407323         NaN                    top narrow based indexes august
# 1407324         NaN     recap wednesdays top percentage gainers losers
# 1407325         NaN  update oppenheimer color china zenix auto init...
# 1407326         NaN    oppenheimer initiates china zenix outperform pt
# 1407327         NaN  china zenix auto international opens trading i...
#
# [1407328 rows x 10 columns]

# %%
# df=ta.text_preprocess()
result=text_analyser.get_sentiment()
result
# Out:
#                                                   headline  \
# 0                  Stocks That Hit 52-Week Highs On Friday
# 1               Stocks That Hit 52-Week Highs On Wednesday
# 2                            71 Biggest Movers From Friday
# 3             46 Stocks Moving In Friday's Mid-Day Session
# 4        B of A Securities Maintains Neutral on Agilent...
# ...                                                    ...
# 1407323             Top Narrow Based Indexes For August 29
# 1407324  Recap: Wednesday's Top Percentage Gainers and ...
# 1407325  UPDATE: Oppenheimer Color on China Zenix Auto ...
# 1407326  Oppenheimer Initiates China Zenix At Outperfor...
# 1407327  China Zenix Auto International Opens For Tradi...
#
#                                                        url          publisher  \
# 0        https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1        https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2        https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3        https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4        https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
# ...                                                    ...                ...
# 1407323  https://www.benzinga.com/news/11/08/1888782/to...      Monica Gerson
# 1407324  https://www.benzinga.com/news/earnings/11/06/1...       Benjamin Lee
# 1407325  https://www.benzinga.com/analyst-ratings/analy...     BenzingaStaffL
# 1407326  https://www.benzinga.com/analyst-ratings/price...          Joe Young
# 1407327  https://www.benzinga.com/news/ipos/11/05/10789...      Allie Wickman
#
#                              date stock  headline_length    year  month  \
# 0       2020-06-05 14:30:54+00:00     A               39  2020.0    6.0
# 1       2020-06-03 14:45:20+00:00     A               42  2020.0    6.0
# 2       2020-05-26 08:30:07+00:00     A               29  2020.0    5.0
# 3       2020-05-22 16:45:06+00:00     A               44  2020.0    5.0
# 4       2020-05-22 15:38:59+00:00     A               87  2020.0    5.0
# ...                           ...   ...              ...     ...    ...
# 1407323                       NaT    ZX               38     NaN    NaN
# 1407324                       NaT    ZX               52     NaN    NaN
# 1407325                       NaT    ZX               56     NaN    NaN
# 1407326                       NaT    ZX               54     NaN    NaN
# 1407327                       NaT    ZX               81     NaN    NaN
#
#         day_of_week                                   cleaned_headline  \
# 0            Friday                       stocks hit week highs friday
# 1         Wednesday                    stocks hit week highs wednesday
# 2           Tuesday                              biggest movers friday
# 3            Friday               stocks moving fridays midday session
# 4            Friday  b securities maintains neutral agilent technol...
# ...             ...                                                ...
# 1407323         NaN                    top narrow based indexes august
# 1407324         NaN     recap wednesdays top percentage gainers losers
# 1407325         NaN  update oppenheimer color china zenix auto init...
# 1407326         NaN    oppenheimer initiates china zenix outperform pt
# 1407327         NaN  china zenix auto international opens trading i...
#
#          polarity sentiment
# 0            0.00   Neutral
# 1            0.00   Neutral
# 2            0.00   Neutral
# 3            0.00   Neutral
# 4            0.00   Neutral
# ...           ...       ...
# 1407323      0.15  positive
# 1407324      0.15  positive
# 1407325      0.00   Neutral
# 1407326      0.00   Neutral
# 1407327      0.00   Neutral
#
# [1407328 rows x 12 columns]

# %%
text_analyser.plot_sentiment_distribution()
# Out:
# sentiment
# Neutral     969425
# positive    329714
# Negative    108189
# Name: count, dtype: int64

# %%
print(text_analyser.text_preprocess().columns)
# Out:
# Index(['headline', 'url', 'publisher', 'date', 'stock', 'headline_length',
#        'year', 'month', 'day_of_week', 'cleaned_headline', 'polarity',
#        'sentiment'],
#       dtype='object')

# %%
text_analyser.word_frequency()

# %%
keywords=text_analyser.extract_keywords()

# %%
print("Sentiment Analysis Results:")
print("\nExtracted Keywords:")
print(keywords)
# Out:
# Sentiment Analysis Results:
#
# Extracted Keywords:
# ['eps' 'est' 'shares' 'stocks' 'vs']

# %%
topics = text_analyser.perform_topic_modeling()
print("\nIdentified Topics:")
print(topics)

# %% [markdown]
# Time Series Analysis
